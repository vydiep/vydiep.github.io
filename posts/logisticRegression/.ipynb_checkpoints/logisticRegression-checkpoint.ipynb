# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from logisticRegression import LogisticRegression

# %%
from sklearn.datasets import make_blobs
from matplotlib import pyplot as plt
import numpy as np
np.seterr(all='ignore') 

# make the data
p_features = 3
X, y = make_blobs(n_samples = 200, n_features = p_features - 1, centers = [(-1, -1), (1, 1)])

fig = plt.scatter(X[:,0], X[:,1], c = y)
xlab = plt.xlabel("Feature 1")
ylab = plt.ylabel("Feature 2")

# %%
# fit the model

LR = LogisticRegression()
LR.fit(X, y, alpha = 0.1, epochs = 1000)

# inspect the fitted value of w
LR.w 

fig = plt.scatter(X[:,0], X[:,1], c = y)
xlab = plt.xlabel("Feature 1")
ylab = plt.ylabel("Feature 2")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/y2/rws46lgn3vl7w4ls0yqgcg1r0000gn/T/ipykernel_25516/3972492077.py in <module>
#       2
#       3 LR = LogisticRegression()
# ----> 4 LR.fit(X, y, alpha = 0.1, epochs = 1000)
#       5
#       6 # inspect the fitted value of w
#
# ~/Desktop/cs/csci0451/logisticRegression.py in fit(self, X, y, alpha, epochs)
#      17
#      18         for epoch in range(self.epochs):
# ---> 19             y_pred = self.sigmoid(X @ self.w)
#      20
#      21             grad = np.dot(X.T, y_pred - y)
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 4 is different from 3)
